# %% [markdown]
# <button data-commandLinker-command="notebook:run-all-cells" style="background:#286e60;color:white;border:0;border-radius:5px;padding:11px 18px;font-weight:600;cursor:pointer">Open / refresh workbench</button>
#
# Click above once when you open this notebook. **Run → Run All Cells** does the same thing.
#
# In a lesson, **Shift+Enter** runs a cell. Double-click text to edit your answers. **Ctrl+S** saves code and notebook answers;
# notes and checkboxes in the panels save automatically.

# %%
from pathlib import Path
import sys
project = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / "curriculum.json").is_file())
if str(project) not in sys.path:
    sys.path.insert(0, str(project))

from workbench import home
display(home())
