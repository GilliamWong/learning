# %% [markdown]
# <button data-commandLinker-command="notebook:run-all-cells" style="background:#286e60;color:white;border:0;border-radius:5px;padding:10px 16px;cursor:pointer">Open paper reader</button>
#
# Click above, then use **Previous**, **Next**, or the page number. **Text** provides selectable page text.
# Your last page is saved locally. The original PDF remains unchanged in `library/papers/`.

# %%
from pathlib import Path
import sys
project = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / "curriculum.json").is_file())
if str(project) not in sys.path:
    sys.path.insert(0, str(project))
from workbench.reader import paper_reader
display(paper_reader("induction"))
