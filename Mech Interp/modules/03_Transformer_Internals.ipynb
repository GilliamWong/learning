# %% [markdown]
# # 03 · Inside a transformer
#
# Run the panel below to save progress and notes. The guide follows it.

# %%
from pathlib import Path
import sys
project = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / "curriculum.json").is_file())
if str(project) not in sys.path:
    sys.path.insert(0, str(project))

from workbench import lesson_panel, check

display(lesson_panel("03"))

# %% [markdown]
# ## What is ready here
#
# This notebook organizes the reading, implementation milestones, and your notes.
# The implementation exercises are in the imported ARENA notebook, linked in the panel above.
# Open the local exercise copy with its **ARENA (local GPU)** kernel and run the local setup cell.
# Use [your study plan](../LEARNING_PLAN.md) for the detailed reading and coding order.
#
# ## 1. Read with a question
#
# Read **Transformer Overview**, especially **High-Level Architecture** and **Virtual Weights and the Residual Stream
# as a Communication Channel**, in [A Mathematical Framework for Transformer Circuits](https://transformer-circuits.pub/2021/framework/index.html).
# Your question is: *what is the evolving representation at one token position, and how can different components change it?*
# Pause the more involved circuit algebra until you have an implementation to relate it to.
#
# **My current account of the residual stream:**
#
# *Write here. Mark anything you are uncertain about.*
#
# ## 2. Implement through ARENA 1.1
#
# Open [the local Transformers from Scratch exercises](../arena/notebooks/chapter1_transformer_interp/part1_transformer_from_scratch/1.1_Transformer_from_Scratch_exercises.ipynb).
# Work through **Understanding Inputs & Outputs**, then **Clean Transformer Implementation**.
# For each component, write the input and output dimensions before coding. Verify the assembled model using the exercise's pretrained-weight checks.
# Run the basic training example and try initial sampling. Advanced beam search and KV caching can wait.
#
# **Implementation record:**
#
# | Component | My dimension explanation | Verified? | Remaining question |
# |---|---|---|---|
# | Token and position embeddings | | | |
# | Layer normalization | | | |
# | Attention | | | |
# | MLP | | | |
# | Residual block | | | |
# | Output scores | | | |
#
# ## 3. Explain one prediction
#
# Choose a short prompt from the exercise. Trace how its tokens become scores for the next token.
# Describe what is shared across positions and what lets one position use information from another.
#
# **My explanation:**
#
# *Write here.*
#
# ## Optional research orientation
#
# Revisit the transformer-basics subsection of Stage 1 in [Neel's researcher guide](https://www.alignmentforum.org/posts/jP9KDyMkchuv6tHwm/how-to-become-a-mechanistic-interpretability-researcher).
# Record one skill that is now easier and one concrete gap to address in an experiment.
#
# ## Next step
#
# When you can explain the core computations and verify the model, move to [04 · Induction heads](04_Induction_Heads.ipynb).
