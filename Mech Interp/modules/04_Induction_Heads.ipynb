# %% [markdown]
# # 04 · Find an induction mechanism
#
# Run the panel below to save progress and notes. The guide follows it.

# %%
from pathlib import Path
import sys
project = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / "curriculum.json").is_file())
if str(project) not in sys.path:
    sys.path.insert(0, str(project))

from workbench import lesson_panel, check

display(lesson_panel("04"))

# %% [markdown]
# ## Scope
#
# This is a guide into a paper and ARENA's experiment notebook. Model execution uses the local ARENA (local GPU) kernel.
# Start with a selected result. Record explicitly which model, data, and intervention your reproduction uses.
#
# ## 1. Preview the paper
#
# Open the [local induction-head paper](../library/readers/Induction_Heads.ipynb).
# Read the introduction and the definition of induction heads. Inspect one relevant figure.
# Record the authors' broad hypothesis and distinguish it from the narrower claim you can test on a small model.
#
# **Broad hypothesis:**
#
# *Write here.*
#
# **A narrow claim I could investigate:**
#
# *Write here.*
#
# ## 2. Observe a model
#
# Use [the local ARENA 1.2 exercises](../arena/notebooks/chapter1_transformer_interp/part2_intro_to_mech_interp/1.2_Intro_to_Mech_Interp_exercises.ipynb), sections 1–3:
# loading and caching, finding induction heads, and hooks. Before inspecting a repeated-token example,
# draw the attention pattern you expect and explain your prediction.
#
# **Prediction before observing:**
#
# *Write here.*
#
# **Observation and any mismatch:**
#
# *Write here.*
#
# ## 3. Select one result to reproduce
#
# For an intervention result, read **Argument 3 (Direct ablation)** and the relevant methods in the paper.
# Write down the exact figure or claim you selected, the metric, and the control comparison.
# If you use a different model or data distribution, label the work as an adapted experiment.
#
# | Choice | My specification |
# |---|---|
# | Exact figure or claim | |
# | Model and checkpoint | |
# | Data and sequence construction | |
# | Metric | |
# | Intervention | |
# | Control comparison | |
# | Differences from the paper | |
#
# ## 4. Investigate one variation
#
# One possible direction is the distance between repeated tokens. Choose your own prediction first.
# Use many examples and separate exploration examples from fresh evaluation examples.
# An intervention's effect should be interpreted in the context of its controls and possible general damage to the model.
#
# **What I predict:**
#
# *Write here.*
#
# **What changed and what stayed fixed:**
#
# *Write here.*
#
# ## 5. Distill the result
#
# Write one observation, one inference, and one remaining uncertainty. Save runnable work in an experiment notebook.
# The **Your work** tab on the home page creates one from a template.
#
# Continue to [05 · Causal circuits](05_Causal_Circuits.ipynb) when you can explain your experiment and its practical limits.
