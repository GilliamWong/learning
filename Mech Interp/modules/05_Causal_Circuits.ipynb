# %% [markdown]
# # 05 · Test a circuit explanation
#
# Run the panel below to save progress and notes. The guide follows it.

# %%
from pathlib import Path
import sys
project = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / "curriculum.json").is_file())
if str(project) not in sys.path:
    sys.path.insert(0, str(project))

from workbench import lesson_panel, check

display(lesson_panel("05"))

# %% [markdown]
# ## Scope
#
# This guide pairs the [local IOI paper](../library/readers/Indirect_Object_Identification.ipynb) with
# [ARENA's IOI exercises](https://learn.arena.education/chapter1_transformer_interp/21_ioi/).
# The first target is one selected result. Use the official exercise's setup for model execution.
#
# ## 1. Define the task and metric
#
# Read the paper's task definition. Describe what the model is supposed to predict and how its behavior is measured.
# Then read the method used for the result you want to reproduce.
#
# **Task, metric, and selected claim:**
#
# *Write here.*
#
# ## 2. Learn the intervention
#
# Complete ARENA's **Model & Task Setup**, **Logit Attribution**, and **Activation Patching** sections.
# Explain what is changed, what is preserved, and how the resulting metric supports or weakens your hypothesis.
# Inspect simpler observations to form hypotheses, then use interventions to test them.
#
# **My explanation of the patching experiment:**
#
# *Write here.*
#
# ## 3. Reproduce and check
#
# Record the exact source figure or claim, model identity, prompt construction, metric, and intervention.
# Include baseline behavior and controls. Record discrepancies even when the overall picture looks similar.
# When using educational simplifications or a different setup, describe the result as an adaptation.
#
# **Agreement with the selected result:**
#
# *Write here.*
#
# **Discrepancies and checks:**
#
# *Write here.*
#
# ## 4. Decide whether to deepen or branch
#
# ARENA's later sections cover path patching and a fuller replication. Follow them if they help answer your question.
# Otherwise, use the methods you now understand to investigate a small variation.
#
# **Next decision and reason:**
#
# *Write here.*
#
# Continue to [06 · Independent experiments](06_Independent_Experiments.ipynb) for the research scaffold.
