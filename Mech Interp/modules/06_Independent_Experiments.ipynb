# %% [markdown]
# # 06 · Choose your own question
#
# Run the panel below to save progress and notes. The guide follows it.

# %%
from pathlib import Path
import sys
project = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / "curriculum.json").is_file())
if str(project) not in sys.path:
    sys.path.insert(0, str(project))

from workbench import lesson_panel, check

display(lesson_panel("06"))

# %% [markdown]
# ## Start with a bounded question
#
# Use **Your work → New experiment** on the home page to create a separate notebook.
# Choose a question you can begin testing with your existing code and available compute.
# Read the relevant prior work before treating a result as new.
#
# Possible starting points include a sensitivity check on a replicated result, a different input distribution,
# or a failure case that your current explanation does not predict.
#
# ## Before running
#
# - State the hypothesis and one plausible alternative.
# - Identify a measurable outcome and a control comparison.
# - Record the model, data, seeds, and important settings.
# - Decide what result would change your mind.
# - Define a small pilot and a stopping or reassessment point.
#
# **My question and why it is worth testing:**
#
# *Write here.*
#
# ## Paper reading follows the experiment
#
# Preview papers to find relevant claims. Read methods in detail when using or challenging those claims.
# Record the exact sections you read and the questions they resolve in a paper-note notebook.
# The aim is to build an explanation that survives useful tests.
#
# ## Optional representations branch
#
# The reading library includes the [local Toy Models of Superposition paper](../library/readers/Toy_Models_of_Superposition.ipynb).
# Start with the toy setup and choose one small configuration if you want a controlled implementation project.
#
# Goodfire's [Understanding and Steering Llama 3 with Sparse Autoencoders](https://www.goodfire.com/research/understanding-and-steering-llama-3)
# and [Under the Hood of a Reasoning Model](https://www.goodfire.com/research/under-the-hood-of-a-reasoning-model)
# provide later applied reading. Choose a specific claim and identify what evidence supports it.
# These readings do not require an account; a large-model reproduction is a separate compute and setup decision.
#
# ## End each experiment with a decision
#
# What did you learn? What remains uncertain? Is the next useful step another check, a narrower question,
# a different approach, or writing up the result? Save the decision and a concrete next action.
#
# Return [home](../00_Start_Here.ipynb) to create the notebook and keep your questions and sources together.
