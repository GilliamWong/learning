# %% [markdown]
# # Experiment · rename this title
#
# **Question:**
#
# **Prior work and exact result I am building on:**
#
# **Hypothesis and alternative explanation:**
#
# **Prediction before running:**
#
# **What would change my mind:**

# %% [markdown]
# ## Setup and scope
#
# Record the model/checkpoint, dataset or prompt construction, split, seeds, metric, intervention,
# baseline, controls, and compute budget. Note deviations from any paper's setup.

# %%
# Record settings before the experiment. Add the imports and values you actually use.
settings = {"seed": 0, "model": "", "data": "", "metric": ""}

# %% [markdown]
# ## Pilot and checks
#
# Check a few actual examples, shapes, baseline outputs, and the intended intervention.
# Describe how you will recognize a broken experiment.

# %%
# Your pilot experiment here.

# %% [markdown]
# ## Results
#
# Save the code that produces each table or figure. Label measurements and include controls.

# %%
# Your measurement and plotting code here.

# %% [markdown]
# ## Interpretation
#
# **Observation:**
#
# **Inference and supporting evidence:**
#
# **Uncertainty or alternative explanation:**
#
# **Differences from the source result, if applicable:**
#
# ## Next decision
#
# Continue, narrow, change approach, or write up? Why?
#
# **Next time, start with:**
#
# ## Reproduction check
#
# Save the notebook. Restart the kernel and rerun the experiment before treating it as reproducible.
# Record any external inputs or environment requirements needed by someone else to rerun it.
