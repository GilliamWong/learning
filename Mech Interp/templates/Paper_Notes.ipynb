# %% [markdown]
# # Paper note · rename this title
#
# **Title and authors:**
#
# **Source URL / local PDF / version:**
#
# **Why I am reading it now:**
#
# **Reading depth and exact sections:** preview / selected sections / reproduce one result

# %% [markdown]
# ## Before reading closely
#
# What question do I want the paper to answer? What do I currently expect?
#
# *Write here.*
#
# ## Central claim and scope
#
# What is the claim? Which model, data, and conditions does the evidence cover?
#
# *Write here.*
#
# ## One figure or method I can explain
#
# Identify it precisely. Explain the axes, comparison, or intervention in your own words.
#
# *Write here.*
#
# ## Evidence, alternatives, and limits
#
# What supports the claim? Which alternatives have or have not been ruled out?
#
# *Write here.*
#
# ## Connection to my code
#
# Link the exercise or experiment this reading informs. What changed in your understanding?
#
# *Write here.*
#
# ## Next reading or experiment
#
# Leave one concrete action. Park unrelated questions below.
#
# *Write here.*
